# %% [markdown]
# <a href="https://colab.research.google.com/github/HARSHITHA24MANVI/AI-Lab-5H/blob/main/Harshithamanvi__week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def print_board(board):
    """Prints the current state of the board in a scannable grid layout."""
    print("\n")
    print(f" {board[0]} | {board[1]} | {board[2]} ")
    print("---|---|---")
    print(f" {board[3]} | {board[4]} | {board[5]} ")
    print("---|---|---")
    print(f" {board[6]} | {board[7]} | {board[8]} ")
    print("\n")

def check_winner(board, player):
    """Checks if the given player has won the game."""
    # Winning combinations: 3 horizontal, 3 vertical, 2 diagonal
    win_conditions = [
        [0, 1, 2], [3, 4, 5], [6, 7, 8],  # Rows
        [0, 3, 6], [1, 4, 7], [2, 5, 8],  # Columns
        [0, 4, 8], [2, 4, 6]              # Diagonals
    ]
    for condition in win_conditions:
        if board[condition[0]] == board[condition[1]] == board[condition[2]] == player:
            return True
    return False

def check_tie(board):
    """Checks if the board is completely full (a tie game)."""
    return " " not in board

def tic_tac_toe():
    """Main function to run the Tic-Tac-Toe game loop."""
    # Initialize an empty board with spaces
    board = [" "] * 9
    current_player = "X"

    print("Welcome to Tic-Tac-Toe!")
    print("Positions are layout out from 1 to 9 like this:")
    print(" 1 | 2 | 3 \n---|---|---\n 4 | 5 | 6 \n---|---|---\n 7 | 8 | 9 ")

    while True:
        print_board(board)

        # Get and validate player input
        try:
            choice = int(input(f"Player {current_player}'s turn. Choose a position (1-9): ")) - 1
            if choice < 0 or choice > 8:
                print("Invalid input! Please choose a number between 1 and 9.")
                continue
            if board[choice] != " ":
                print("That position is already taken! Try another one.")
                continue
        except ValueError:
            print("Invalid input! Please enter a valid number.")
            continue

        # Place the move on the board
        board[choice] = current_player

        # Check for game over conditions
        if check_winner(board, current_player):
            print_board(board)
            print(f"🎉 Congratulations! Player {current_player} wins the game! 🎉")
            break

        if check_tie(board):
            print_board(board)
            print("🤝 It's a draw! Well played both.")
            break

        # Switch turns between 'X' and 'O'
        current_player = "O" if current_player == "X" else "X"

if __name__ == "__main__":
    tic_tac_toe()
# Out:
# Welcome to Tic-Tac-Toe!
# Positions are layout out from 1 to 9 like this:
#  1 | 2 | 3
# ---|---|---
#  4 | 5 | 6
# ---|---|---
#  7 | 8 | 9
#
#
#    |   |
# ---|---|---
#    |   |
# ---|---|---
#    |   |
#
#
# Player X's turn. Choose a position (1-9): 1
#
#
#  X |   |
# ---|---|---
#    |   |
# ---|---|---
#    |   |
#
#
# Player O's turn. Choose a position (1-9): 2
#
#
#  X | O |
# ---|---|---
#    |   |
# ---|---|---
#    |   |
#
#
# Player X's turn. Choose a position (1-9): 3
#
#
#  X | O | X
# ---|---|---
#    |   |
# ---|---|---
#    |   |
#
#
# Player O's turn. Choose a position (1-9): 5
#
#
#  X | O | X
# ---|---|---
#    | O |
# ---|---|---
#    |   |
#
#
# Player X's turn. Choose a position (1-9): 6
#
#
#  X | O | X
# ---|---|---
#    | O | X
# ---|---|---
#    |   |
#
#
# Player O's turn. Choose a position (1-9): 8
#
#
#  X | O | X
# ---|---|---
#    | O | X
# ---|---|---
#    | O |
#
#
# 🎉 Congratulations! Player O wins the game! 🎉
